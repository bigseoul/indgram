# %%
import dart_fss as dart
from dart_fss.api import info
import pandas as pd

# API 키 설정(환경변수 DART_API_KEY를 쓰면 생략 가능)
dart.set_api_key(api_key="888e4aca3aba61a62811ba87e0fc054e2d9f6ea0")

corp = '00296324'
