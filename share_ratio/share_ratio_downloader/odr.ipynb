# %% [markdown]
# ## 정기 공시 대상

# %%
import OpenDartReader
import pandas as pd


api_key = '888e4aca3aba61a62811ba87e0fc054e2d9f6ea0'

dart = OpenDartReader(api_key)

# %%
dart.report('00296324','타법인출자', 2024)
# Out:
#           rcept_no corp_cls corp_code corp_name            inv_prm  \
# 0   20250320001151        K  00296324     큐로홀딩스           ㈜크레오에스지
# 1   20250320001151        K  00296324     큐로홀딩스              큐비트㈜
# 2   20250320001151        K  00296324     큐로홀딩스         블록체인유니버스㈜
# 3   20250320001151        K  00296324     큐로홀딩스        큐로컴에너지 LLC
# 4   20250320001151        K  00296324     큐로홀딩스           ㈜큐로에프앤비
# 5   20250320001151        K  00296324     큐로홀딩스              케이피㈜
# 6   20250320001151        K  00296324     큐로홀딩스            ㈜더원게임즈
# 7   20250320001151        K  00296324     큐로홀딩스   일본정밀(JASDAQ상장)
# 8   20250320001151        K  00296324     큐로홀딩스            ㈜에이트웍스
# 9   20250320001151        K  00296324     큐로홀딩스             ㈜필리에라
# 10  20250320001151        K  00296324     큐로홀딩스          ㈜큐로트레이더스
# 11  20250320001151        K  00296324     큐로홀딩스                 합계
#
#    frst_acqs_de invstmnt_purps frst_acqs_amount bsis_blce_qy  \
# ...

# %%
dart.report('00296324','최대주주', 2024)
# Out:
#           rcept_no corp_cls corp_code corp_name stock_knd           nm  \
# 0   20250320001151        K  00296324     큐로홀딩스       보통주    케이파트너스(주)
# 1   20250320001151        K  00296324     큐로홀딩스       보통주    (주)큐로에프앤비
# 2   20250320001151        K  00296324     큐로홀딩스       보통주          김동준
# 3   20250320001151        K  00296324     큐로홀딩스       보통주    (주)크레오에스지
# 4   20250320001151        K  00296324     큐로홀딩스       보통주       (주)지엔코
# 5   20250320001151        K  00296324     큐로홀딩스       보통주  큐캐피탈파트너스(주)
# 6   20250320001151        K  00296324     큐로홀딩스       보통주     (주)원업플러스
# 7   20250320001151        K  00296324     큐로홀딩스       보통주          권기대
# 8   20250320001151        K  00296324     큐로홀딩스       보통주          권기환
# 9   20250320001151        K  00296324     큐로홀딩스       보통주          권경훈
# 10  20250320001151        K  00296324     큐로홀딩스       보통주  (주)이뮤노백스바이오
# 11  20250320001151        K  00296324     큐로홀딩스       보통주            계
# ...

# %% [markdown]
# ## 외감 대상
# 기존 라이브러리로 알아낼 수 없음.
# 케이파트너스

# %%
dart.report('00973681','최대주주', 2024)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Empty DataFrame
# Columns: []
# Index: []
