# %% [markdown]
# ## 정기 공시 대상

# %%
import OpenDartReader


api_key = '888e4aca3aba61a62811ba87e0fc054e2d9f6ea0'

dart = OpenDartReader(api_key)

# %%
dart.report('00806228', '최대주주', 2024)[['corp_name', 'nm']]
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dart.report('00806228', '최대주주', 2024)[['corp_name', 'nm']]
#
# File ~/Documents/workspace/indgram/.venv/lib/python3.14/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/workspace/indgram/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
dart.report('00806228','타법인출자', 2024)[['corp_name','inv_prm' ]]
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dart.report('00129059','타법인출자', 2024)[['corp_name','inv_prm' ]]
#
# File ~/Documents/workspace/indgram/.venv/lib/python3.14/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/workspace/indgram/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
dart.report('00806228','최대주주', 2024)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 외감 대상
# 기존 라이브러리로 알아낼 수 없음.
# 케이파트너스

# %%
dart.report('00973681','최대주주', 2024)
# Out:
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}
# Empty DataFrame
# Columns: []
# Index: []
