# %%
import OpenDartReader

api_key = '888e4aca3aba61a62811ba87e0fc054e2d9f6ea0'
dart = OpenDartReader(api_key) 

# 회사 리스트 조회

# %%
### 1. 공시정보 ###
# 특정기업(삼성전자) 상장이후 모든 공시 목록 (5,600 건+)
dart.list('삼성전자') # 기업이름 혹은,
# Out:
#      corp_code corp_name stock_code corp_cls              report_nm  \
# 0     00126380      삼성전자     005930        Y  동일인등출자계열회사와의상품ㆍ용역거래변경
# 1     00126380      삼성전자     005930        Y  동일인등출자계열회사와의상품ㆍ용역거래변경
# 2     00126380      삼성전자     005930        Y  동일인등출자계열회사와의상품ㆍ용역거래변경
# 3     00126380      삼성전자     005930        Y        분기보고서 (2025.09)
# 4     00126380      삼성전자     005930        Y    임원ㆍ주요주주특정증권등소유상황보고서
# ...        ...       ...        ...      ...                    ...
# 6817  00126380      삼성전자     005930        Y           채무보증(담보제공포함)
# 6818  00126380      삼성전자     005930        Y          최대주주등을위한금전의대여
# 6819  00126380      삼성전자     005930        Y        감사보고서 (1999.12)
# 6820  00126380      삼성전자     005930        Y  [기재정정]반기보고서 (1999.06)
# 6821  00126380      삼성전자     005930        Y  [기재정정]사업보고서 (1998.12)
#
#             rcept_no         flr_nm  rcept_dt rm
# 0     20251114002640           삼성전자  20251114  공
# 1     20251114002617           삼성전자  20251114  공
# 2     20251114002592           삼성전자  20251114  공
# 3     20251114002447           삼성전자  20251114
# 4     20251111000088  SONG TAEKSANG  20251111
# ...              ...            ...       ... ..
# 6817  20000404000429           삼성전자  20000404
# 6818  20000401000031           삼성전자  20000401
# 6819  20000320000124         삼일회계법인  20000320
# 6820  19990824000003           삼성전자  19990824
# 6821  19990626000007           삼성전자  19990626  연
#
# [6822 rows x 9 columns]

# %% [markdown]
# ## 개별 회사 상세 정보 확인하기
# company() - 기업개황

# %%
dart.company("00126380")
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '전영현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.samsung.com/sec',
#  'ir_url': '',
#  'phn_no': '02-2255-0114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}
